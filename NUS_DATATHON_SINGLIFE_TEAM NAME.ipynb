# %% [markdown]
# ##### The cell below is for you to keep track of the libraries used and install those libraries quickly
# ##### Ensure that the proper library names are used and the syntax of `%pip install PACKAGE_NAME` is followed

# %%
#%pip install pandas 
#%pip install matplotlib
# add commented pip installation lines for packages used as shown above for ease of testing
# the line should be of the format %pip install PACKAGE_NAME

# %% [markdown]
# ## **DO NOT CHANGE** the filepath variable
# ##### Instead, create a folder named 'data' in your current working directory and
# ##### have the .parquet file inside that. A relative path *must* be used when loading data into pandas

# %%
# Can have as many cells as you want for code
import pandas as pd
filepath = "./data/catB_train.parquet" 
# the initialised filepath MUST be a relative path to a folder named data that contains the parquet file

# %% [markdown]
# ### **ALL** Code for machine learning and dataset analysis should be entered below.
# ##### Ensure that your code is clear and readable.
# ##### Comments and Markdown notes are advised to direct attention to pieces of code you deem useful.

# %%
df = pd.read_parquet(filepath)

df
# Out:
#           clntnum race_desc ctrycode_desc clttype stat_flag min_occ_date  \
# 19550  91b546e924   Chinese     Singapore       P    ACTIVE   2017-10-31
# 4600   896bae548c   Chinese     Singapore       P    ACTIVE   2007-05-23
# 13337  f364439ae6    Others     Singapore       P    ACTIVE   2019-08-31
# 15074  70f319cfe1   Chinese     Singapore       P    ACTIVE   2021-10-18
# 19724  2647a81328   Chinese     Singapore       P    ACTIVE   2018-07-20
# ...           ...       ...           ...     ...       ...          ...
# 11284  3363260248      None     Singapore       P    LAPSED   2016-08-01
# 11964  c3509f0aef   Chinese     Singapore       P    ACTIVE   1990-03-20
# 5390   6e44cfb3e7   Chinese     Singapore       P    ACTIVE   2007-12-31
# 860    dd4e362f9f    Others     Singapore       P    ACTIVE   2007-09-01
# 15795  3788d06ec7    Indian     Singapore       P    ACTIVE   2011-10-24
#
#        cltdob_fix cltsex_fix  flg_substandard  flg_is_borderline_standard  \
# 19550  1974-05-09     Female              0.0                         0.0
# 4600   1979-11-11       Male              0.0                         0.0
# 13337  1976-01-28       Male              0.0                         0.0
# 15074  1976-03-19     Female              0.0                         0.0
# 19724  1995-07-31     Female              0.0                         0.0
# ...           ...        ...              ...                         ...
# 11284  1994-05-24       Male              0.0                         0.0
# 11964  1948-12-16       Male              0.0                         0.0
# 5390   1967-12-06     Female              0.0                         0.0
# 860    1986-04-01       Male              0.0                         0.0
# 15795  1970-05-15       Male              0.0                         0.0
#
#        ...  recency_giclaim  giclaim_cnt_success  recency_giclaim_success  \
# 19550  ...              NaN                 None                     None
# 4600   ...              NaN                 None                     None
# 13337  ...              NaN                 None                     None
# 15074  ...              NaN                 None                     None
# 19724  ...              NaN                 None                     None
# ...    ...              ...                  ...                      ...
# 11284  ...              NaN                 None                     None
# 11964  ...              NaN                 None                     None
# 5390   ...              NaN                 None                     None
# 860    ...              NaN                 None                     None
# 15795  ...              NaN                 None                     None
#
#        giclaim_cnt_unsuccess  recency_giclaim_unsuccess  \
# 19550                   None                       None
# 4600                    None                       None
# 13337                   None                       None
# 15074                   None                       None
# 19724                   None                       None
# ...                      ...                        ...
# 11284                   None                       None
# 11964                   None                       None
# 5390                    None                       None
# 860                     None                       None
# 15795                   None                       None
#
#        flg_gi_claim_29d435_ever  flg_gi_claim_058815_ever  \
# 19550                      None                      None
# 4600                       None                      None
# 13337                      None                      None
# 15074                      None                      None
# 19724                      None                      None
# ...                         ...                       ...
# 11284                      None                      None
# 11964                      None                      None
# 5390                       None                      None
# 860                        None                      None
# 15795                      None                      None
#
#        flg_gi_claim_42e115_ever  flg_gi_claim_856320_ever  f_purchase_lh
# 19550                      None                      None            NaN
# 4600                       None                      None            NaN
# 13337                      None                      None            NaN
# 15074                      None                      None            NaN
# 19724                      None                      None            NaN
# ...                         ...                       ...            ...
# 11284                      None                      None            NaN
# 11964                      None                      None            NaN
# 5390                       None                      None            NaN
# 860                        None                      None            NaN
# 15795                      None                      None            NaN
#
# [17992 rows x 304 columns]

# %%
numerical_stats = df.describe()
modes = numerical_stats.mode().iloc[0]
numerical_stats.loc["mode"] = modes
numerical_stats.loc["mode_freq"] = modes / len(df) * 100
numerical_stats
# Out:
#            flg_substandard  flg_is_borderline_standard  flg_is_revised_term  \
# count         16978.000000                16978.000000         16978.000000
# mean              0.040287                    0.033102             0.000707
# std               0.196638                    0.178907             0.026577
# min               0.000000                    0.000000             0.000000
# 25%               0.000000                    0.000000             0.000000
# 50%               0.000000                    0.000000             0.000000
# 75%               0.000000                    0.000000             0.000000
# max               1.000000                    1.000000             1.000000
# mode              0.000000                    0.000000             0.000000
# mode_freq         0.000000                    0.000000             0.000000
#
#            flg_is_rental_flat  flg_has_health_claim  flg_has_life_claim  \
# count            16978.000000          16978.000000        16978.000000
# mean                 0.012546              0.048769            0.003593
# std                  0.111306              0.215391            0.059835
# min                  0.000000              0.000000            0.000000
# 25%                  0.000000              0.000000            0.000000
# 50%                  0.000000              0.000000            0.000000
# 75%                  0.000000              0.000000            0.000000
# max                  1.000000              1.000000            1.000000
# mode                 0.000000              0.000000            0.000000
# mode_freq            0.000000              0.000000            0.000000
#
#            flg_gi_claim  flg_is_proposal  flg_with_preauthorisation  \
# count      16978.000000     16978.000000               16978.000000
# mean           0.033278         0.002886                   0.008246
# std            0.179368         0.053646                   0.090435
# min            0.000000         0.000000                   0.000000
# 25%            0.000000         0.000000                   0.000000
# 50%            0.000000         0.000000                   0.000000
# 75%            0.000000         0.000000                   0.000000
# max            1.000000         1.000000                   1.000000
# mode           0.000000         0.000000                   0.000000
# mode_freq      0.000000         0.000000                   0.000000
#
#            flg_is_returned_mail  ...  hlthclaim_cnt_success  \
# count              16978.000000  ...            1277.000000
# mean                   0.019260  ...               7.802662
# std                    0.137442  ...              16.005638
# min                    0.000000  ...               1.000000
# 25%                    0.000000  ...               2.000000
# 50%                    0.000000  ...               3.000000
# 75%                    0.000000  ...               8.000000
# max                    1.000000  ...             219.000000
# mode                   0.000000  ...               1.000000
# mode_freq              0.000000  ...               0.005558
#
#            recency_hlthclaim_success  hlthclaim_cnt_unsuccess  \
# count                    1277.000000               610.000000
# mean                       40.870008                 2.455738
# std                        35.084520                 3.694247
# min                         0.000000                 1.000000
# 25%                        10.000000                 1.000000
# 50%                        31.000000                 2.000000
# 75%                        67.000000                 3.000000
# max                       126.000000                68.000000
# mode                        0.000000                 1.000000
# mode_freq                   0.000000                 0.005558
#
#            recency_hlthclaim_unsuccess  flg_hlthclaim_839f8a_ever  \
# count                       610.000000                 285.000000
# mean                         49.409836                   1.000000
# std                          34.932248                   0.000000
# min                           0.000000                   1.000000
# 25%                          18.000000                   1.000000
# 50%                          45.000000                   1.000000
# 75%                          78.000000                   1.000000
# max                         126.000000                   1.000000
# mode                          0.000000                   1.000000
# mode_freq                     0.000000                   0.005558
#
#            recency_hlthclaim_839f8a  flg_hlthclaim_14cb37_ever  \
# count                    285.000000                1375.000000
# mean                      46.077193                   1.000000
# std                       34.288046                   0.000000
# min                        0.000000                   1.000000
# 25%                       18.000000                   1.000000
# 50%                       42.000000                   1.000000
# 75%                       72.000000                   1.000000
# max                      124.000000                   1.000000
# mode                       0.000000                   1.000000
# mode_freq                  0.000000                   0.005558
#
#            recency_hlthclaim_14cb37  recency_giclaim  f_purchase_lh
# count                   1375.000000       448.000000     710.000000
# mean                      42.176000        39.997768       1.000000
# std                       35.548718        30.329252       0.000000
# min                        0.000000         0.000000       1.000000
# 25%                       11.000000        12.000000       1.000000
# 50%                       33.000000        40.000000       1.000000
# 75%                       68.000000        58.000000       1.000000
# max                      126.000000       144.000000       1.000000
# mode                       0.000000         0.000000       1.000000
# mode_freq                  0.000000         0.000000       0.005558
#
# [10 rows x 90 columns]

# %%
df.describe(include=['object'])
# Out:
#            clntnum race_desc ctrycode_desc clttype stat_flag min_occ_date  \
# count        17992     13996         17972   17992     17992        17992
# unique       17992         4            26       3         3         4576
# top     91b546e924   Chinese     Singapore       P    ACTIVE   2023-01-01
# freq             1     10520         17789   14657     17205         1168
#
#        cltdob_fix cltsex_fix  hh_20 pop_20  ... hlthclaim_amt giclaim_amt  \
# count       17992      17969  15183  15183  ...          1449         448
# unique      11076          2    337    869  ...           910         323
# top          None       Male      1      3  ...          0.00        0.00
# freq           22       9773   1353    567  ...           536          86
#
#        giclaim_cnt_success recency_giclaim_success giclaim_cnt_unsuccess  \
# count                    0                       0                     0
# unique                   0                       0                     0
# top                    NaN                     NaN                   NaN
# freq                   NaN                     NaN                   NaN
#
#        recency_giclaim_unsuccess flg_gi_claim_29d435_ever  \
# count                          0                        0
# unique                         0                        0
# top                          NaN                      NaN
# freq                         NaN                      NaN
#
#        flg_gi_claim_058815_ever flg_gi_claim_42e115_ever  \
# count                         0                        0
# unique                        0                        0
# top                         NaN                      NaN
# freq                        NaN                      NaN
#
#        flg_gi_claim_856320_ever
# count                         0
# unique                        0
# top                         NaN
# freq                        NaN
#
# [4 rows x 214 columns]

# %%
df.info()
# 17992 rows by 304 columns
# 90 numerical
# 214 categorical
# target variable is `f_purchase_lh`
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17992 entries, 19550 to 15795
# Columns: 304 entries, clntnum to f_purchase_lh
# dtypes: float64(44), int64(46), object(214)
# memory usage: 41.9+ MB

# %%
categorical_features = df.select_dtypes(exclude="number").columns
numerical_features = df[df.columns.difference(["f_purchase_lh"])].select_dtypes(include="number").columns

print("categorical_features:", categorical_features)
print("numerical_features:", numerical_features)
# Out:
# categorical_features: Index(['clntnum', 'race_desc', 'ctrycode_desc', 'clttype', 'stat_flag',
#        'min_occ_date', 'cltdob_fix', 'cltsex_fix', 'hh_20', 'pop_20',
#        ...
#        'n_months_last_bought_grp_fd3bfb', 'n_months_last_bought_lh_e22a6a',
#        'n_months_last_bought_grp_70e1dd', 'n_months_last_bought_grp_e04c3a',
#        'n_months_last_bought_grp_fe5fb8', 'n_months_last_bought_grp_94baec',
#        'n_months_last_bought_grp_e91421', 'n_months_last_bought_lh_f852af',
#        'n_months_last_bought_lh_947b15', 'n_months_last_bought_32c74c'],
#       dtype='object', length=204)
# numerical_features: Index(['f_elx', 'f_ever_bought_32c74c', 'f_ever_bought_507c37',
#        'f_ever_bought_839f8a', 'f_ever_bought_c4bda5', 'f_ever_bought_d0adeb',
#        'f_ever_bought_e22a6a', 'f_ever_bought_gi', 'f_ever_bought_grp_1581d7',
#        'f_ever_bought_grp_22decf', 'f_ever_bought_grp_6a5788',
#        'f_ever_bought_grp_6fc3e6', 'f_ever_bought_grp_70e1dd',
#        'f_ever_bought_grp_945b5a', 'f_ever_bought_grp_94baec',
#        'f_ever_bought_grp_9cdedf', 'f_ever_bought_grp_caa6ff',
#        'f_ever_bought_grp_de05ae', 'f_ever_bought_grp_e04c3a',
#        'f_ever_bought_grp_e91421', 'f_ever_bought_grp_fd3bfb',
#        'f_ever_bought_grp_fe5fb8', 'f_ever_bought_inv_dcd836',
#        'f_ever_bought_inv_e9f316', 'f_ever_bought_lh_507c37',
#        'f_ever_bought_lh_839f8a', 'f_ever_bought_lh_947b15',
#        'f_ever_bought_lh_d0adeb', 'f_ever_bought_lh_e22a6a',
#        'f_ever_bought_lh_f852af', 'f_ever_bought_ltc',
#        'f_ever_bought_ltc_1280bf', 'f_ever_bought_ltc_43b9d5', 'f_hold_507c37',
#        'f_hold_839f8a', 'f_hold_c4bda5', 'f_hold_d0adeb', 'f_hold_e22a6a',
#        'f_hold_gi', 'f_hold_ltc', 'f_mindef_mha', 'f_retail', 'flg_gi_claim',
#        'flg_has_health_claim', 'flg_has_life_claim',
#        'flg_is_borderline_standard', 'flg_is_proposal', 'flg_is_rental_flat',
#        'flg_is_returned_mail', 'flg_is_revised_term',
#        'flg_latest_being_cancel', 'flg_latest_being_lapse', 'flg_substandard',
#        'flg_with_preauthorisation', 'hh_size', 'is_class_1_2',
#        'is_consent_to_call', 'is_consent_to_email', 'is_consent_to_mail',
#        'is_consent_to_sms', 'is_dependent_in_at_least_1_policy',
#        'is_housewife_retiree', 'is_sg_pr', 'is_valid_dm', 'is_valid_email',
#        'n_months_last_bought_products', 'recency_lapse', 'tot_inforce_pols'],
#       dtype='object')

# %%
df["f_purchase_lh"]
# 7100 1s, 10892 NaN
# Out:
# 19550   NaN
# 4600    NaN
# 13337   NaN
# 15074   NaN
# 19724   NaN
#          ..
# 11284   NaN
# 11964   NaN
# 5390    NaN
# 860     NaN
# 15795   NaN
# Name: f_purchase_lh, Length: 17992, dtype: float64

# %%
from matplotlib import pyplot as plt
# plot histograms for numerical columns
df.hist(figsize=(20,20))
plt.show()

# %%
# Find columns with missing values
count_missing_per_col = df.isna().sum()
percent_missing_per_col = df.isna().mean() * 100
cols_with_nan = pd.DataFrame({'count': count_missing_per_col, 'percentage': percent_missing_per_col})
cols_with_nan = cols_with_nan[cols_with_nan['count'] > 0].sort_values(by='count', ascending=False)
print("====Columns with missing values:====")
print("Cols_with_nan shape:",cols_with_nan.shape)
cols_with_nan # drop cols with over 90% nan, fillna the rest with median values
# Out:
# ====Columns with missing values:====
# Cols_with_nan shape: (111, 2)
#                                    count  percentage
# recency_giclaim_success            17992  100.000000
# flg_gi_claim_856320_ever           17992  100.000000
# flg_gi_claim_42e115_ever           17992  100.000000
# flg_gi_claim_058815_ever           17992  100.000000
# flg_gi_claim_29d435_ever           17992  100.000000
# ...                                  ...         ...
# is_sg_pr                            1014    5.635838
# is_class_1_2                        1014    5.635838
# is_dependent_in_at_least_1_policy   1014    5.635838
# cltsex_fix                            23    0.127835
# ctrycode_desc                         20    0.111161
#
# [111 rows x 2 columns]

# %%
print("Rows with most NaN values:")

# Count the number of NaN values in each row
nan_count_per_row = df.isna().sum(axis=1)

df_check_nan = df.copy()

# Add a new column to the DataFrame with the count of NaN values per row
df_check_nan['nan_count'] = nan_count_per_row

# Calculate the percentage of NaN values
df_check_nan['nan_percent'] = (nan_count_per_row / len(df.columns)) * 100

# Create a DataFrame with count and percent of missing values
rows_w_missing_data = pd.DataFrame({
    'count': nan_count_per_row,
    'percent': df_check_nan['nan_percent']
})

missing_data_sorted = rows_w_missing_data.sort_values(by=['count'], ascending=False)
missing_data_sorted
# Out:
# Rows with most NaN values:
#        count    percent
# 13395    109  35.855263
# 584      109  35.855263
# 9528     109  35.855263
# 1036     109  35.855263
# 6321     109  35.855263
# ...      ...        ...
# 9657      16   5.263158
# 11091     15   4.934211
# 8597      15   4.934211
# 16560     13   4.276316
# 6170      13   4.276316
#
# [17992 rows x 2 columns]

# %%
# Correlation heatmap
import numpy as np
import seaborn as sns

corr_matrix = df.select_dtypes(include=np.number).corr()
np.fill_diagonal(corr_matrix.values, np.nan)
sns.heatmap(corr_matrix, annot=False, cmap='Blues', fmt='g')
np.where(corr_matrix >= 1)
# Out:
# (array([39, 56], dtype=int64), array([56, 39], dtype=int64))

# %%
# remove nan from target and drop target from df
target = df["f_purchase_lh"]
df = df.drop(columns=["f_purchase_lh"])
target = target.fillna(0)

# %%
# Drop columns with more than 90% nan values
cols_to_drop = cols_with_nan[cols_with_nan['percentage'] > 90].index
df = df.drop(columns=cols_to_drop)

# %%
# Fill numerical NaN with median
numerical_columns = df.select_dtypes(include='number').columns
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].median())

# Fill categorical NaN with mode
categorical_columns = df.select_dtypes(exclude='number').columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
# drop useless column
df = df.drop(columns=["clntnum"])
df.head()
# Out:
#       race_desc ctrycode_desc clttype stat_flag min_occ_date  cltdob_fix  \
# 19550   Chinese     Singapore       P    ACTIVE   2017-10-31  1974-05-09
# 4600    Chinese     Singapore       P    ACTIVE   2007-05-23  1979-11-11
# 13337    Others     Singapore       P    ACTIVE   2019-08-31  1976-01-28
# 15074   Chinese     Singapore       P    ACTIVE   2021-10-18  1976-03-19
# 19724   Chinese     Singapore       P    ACTIVE   2018-07-20  1995-07-31
#
#       cltsex_fix  flg_substandard  flg_is_borderline_standard  \
# 19550     Female              0.0                         0.0
# 4600        Male              0.0                         0.0
# 13337       Male              0.0                         0.0
# 15074     Female              0.0                         0.0
# 19724     Female              0.0                         0.0
#
#        flg_is_revised_term  ...  n_months_last_bought_grp_e04c3a  \
# 19550                  0.0  ...                             9999
# 4600                   0.0  ...                             9999
# 13337                  0.0  ...                             9999
# 15074                  0.0  ...                             9999
# 19724                  0.0  ...                             9999
#
#        n_months_last_bought_grp_fe5fb8  n_months_last_bought_grp_94baec  \
# 19550                             9999                             9999
# 4600                              9999                             9999
# 13337                             9999                             9999
# 15074                             9999                             9999
# 19724                             9999                             9999
#
#        n_months_last_bought_grp_e91421  n_months_last_bought_lh_f852af  \
# 19550                             9999                            9999
# 4600                              9999                            9999
# 13337                             9999                            9999
# 15074                             9999                            9999
# 19724                             9999                            9999
#
#        n_months_last_bought_lh_947b15  n_months_last_bought_32c74c  f_elx  \
# 19550                            9999                         9999      0
# 4600                             9999                         9999      0
# 13337                            9999                         9999      0
# 15074                            9999                         9999      0
# 19724                            9999                         9999      0
#
#        f_mindef_mha  f_retail
# 19550             0         1
# 4600              0         1
# 13337             0         1
# 15074             0         1
# 19724             0         1
#
# [5 rows x 271 columns]

# %%
# drop columns with only 1 unique value

# %%
# drop columns with high correlation

# %%
# drop other useless columns based on prior knowledge

# %%
# drop outliers

# %%
# scale numerical columns

# %%
# encode nominal columns

# %%
# encode ordinal columns

# %%
# imblearn SMOTE

# %%
# no idea how to do feature engineering and feature selection

# %%
# to test elasticnet and random forest and xgboost
# test using kfold cross validation
# no idea which metric to use... loss, acc, auc, f1, precision, recall

from sklearn.model_selection import KFold

# %%
# below generated by copilot and i havent checked
class Model:
    def __init__(self, model):
        self.model = model
        self.name = model.__class__.__name__
        self.train_score = None
        self.test_score = None
        self.train_time = None
        self.test_time = None
        self.predictions = None
        self.feature_importances = None

    def __repr__(self):
        return self.name

    def train(self, X_train, y_train):
        start = time.time()
        self.model.fit(X_train, y_train)
        end = time.time()
        self.train_time = end - start
        self.train_score = self.model.score(X_train, y_train)

    def test(self, X_test, y_test):
        start = time.time()
        self.predictions = self.model.predict(X_test)
        end = time.time()
        self.test_time = end - start
        self.test_score = self.model.score(X_test, y_test)

    def get_feature_importances(self, X_train):
        if hasattr(self.model, 'feature_importances_'):
            self.feature_importances = self.model.feature_importances_
        elif hasattr(self.model, 'coef_'):
            self.feature_importances = self.model.coef_
        else:
            print(f"{self.name} does not have feature importances")
            return

        if len(self.feature_importances) != len(X_train.columns):
            print(f"{self.name} feature importances length does not match X_train columns")
            return

        self.feature_importances = pd.DataFrame(self.feature_importances, index=X_train.columns, columns=['importance'])
        self.feature_importances = self.feature_importances.sort_values(by='importance', ascending=False)

    def print_summary(self):
        print(f"Model: {self.name}")
        print(f"Train score: {self.train_score}")
        print(f"Test score: {self.test_score}")
        print(f"Train time: {self.train_time}")
        print(f"Test time: {self.test_time}")
        print(f"Predictions: {self.predictions}")
        print(f"Feature importances: {self.feature_importances}")

# %%
# hyperparameter tuning using ray tune

# %% [markdown]
# ## The cell below is **NOT** to be removed
# ##### The function is to be amended so that it accepts the given input (dataframe) and returns the required output (list).
# ##### It is recommended to test the function out prior to submission
# -------------------------------------------------------------------------------------------------------------------------------
# ##### The hidden_data parsed into the function below will have the same layout columns wise as the dataset *SENT* to you
# ##### Thus, ensure that steps taken to modify the initial dataset to fit into the model are also carried out in the function below

# %%
def testing_hidden_data(hidden_data: pd.DataFrame) -> list:
    '''DO NOT REMOVE THIS FUNCTION.

The function accepts a dataframe as input and return an iterable (list)
of binary classes as output.

The function should be coded to test on hidden data
and should include any preprocessing functions needed for your model to perform. 
    
All relevant code MUST be included in this function.'''
    result = [] 
    return result

# %% [markdown]
# ##### Cell to check testing_hidden_data function

# %%
# This cell should output a list of predictions.
test_df = pd.read_parquet(filepath)
test_df = test_df.drop(columns=["f_purchase_lh"])
print(testing_hidden_data(test_df))
# Out:
# []

# %% [markdown]
# ### Please have the filename renamed and ensure that it can be run with the requirements above being met. All the best!
